# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda_1 = pd.read_csv(url)
tienda_2 = pd.read_csv(url2)
tienda_3 = pd.read_csv(url3)
tienda_4 = pd.read_csv(url4)

# %%
# Lista de DataFrames de las tiendas (según nombres ya cargados en tu notebook)
tiendas = [tienda_1, tienda_2, tienda_3, tienda_4]

# %%
# Normalizar nombres de columnas
for df in [tienda, tienda2, tienda3, tienda4]:
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
        .str.replace("á", "a")
        .str.replace("é", "e")
        .str.replace("í", "i")
        .str.replace("ó", "o")
        .str.replace("ú", "u")
    )

# %%
# Exploración rápida de cada tienda
for i, df in enumerate(tiendas, start=1):
    print(f"\n📌 Tienda {i} - Dimensiones: {df.shape}")
    display(df.head(3))  # Muestra las primeras 3 filas
    print("\nInformación general:")
    print(df.info())
    print("\nValores nulos:")
    print(df.isnull().sum())
    print("\nDescripción numérica:")
    display(df.describe())
# Out:
# 📌 Tienda 1 - Dimensiones: (2359, 12)
#             producto categoria_del_producto    precio  costo_de_envio  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
#
#   fecha_de_compra         vendedor lugar_de_compra  calificacion  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
#
#        metodo_de_pago  cantidad_de_cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# Información general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
# Normalizar columnas: minúsculas y sin espacios
tiendas = [tienda, tienda2, tienda3, tienda4]
for i in range(len(tiendas)):
    tiendas[i].columns = tiendas[i].columns.str.strip().str.lower()

print("\n💰 INGRESO TOTAL POR TIENDA")
for i, df in enumerate(tiendas, start=1):
    ingreso_total = df['precio'].sum()
    print(f"Tienda {i} - Ingreso total: ${ingreso_total:,.2f}")
# Out:
# 💰 INGRESO TOTAL POR TIENDA
# Tienda 1 - Ingreso total: $1,150,880,400.00
# Tienda 2 - Ingreso total: $1,116,343,500.00
# Tienda 3 - Ingreso total: $1,098,019,600.00
# Tienda 4 - Ingreso total: $1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
print("\n📦 VENTAS POR CATEGORÍA")
for i, df in enumerate([tienda, tienda2, tienda3, tienda4], start=1):
    ventas_categoria = df['categoria_del_producto'].value_counts()
    print(f"\nTienda {i} - Ventas por Categoría:")
    print(ventas_categoria)
# Out:
# 📦 VENTAS POR CATEGORÍA
#
# Tienda 1 - Ventas por Categoría:
# categoria_del_producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# Tienda 2 - Ventas por Categoría:
# categoria_del_producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# Tienda 3 - Ventas por Categoría:
# categoria_del_producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
print("\n⭐ CALIFICACIÓN PROMEDIO DE LA TIENDA")
for i, df in enumerate([tienda, tienda2, tienda3, tienda4], start=1):
    promedio_calificacion = df['calificacion'].mean()
    print(f"Tienda {i} - Calificación promedio: {promedio_calificacion:.2f}")
# Out:
# ⭐ CALIFICACIÓN PROMEDIO DE LA TIENDA
# Tienda 1 - Calificación promedio: 3.98
# Tienda 2 - Calificación promedio: 4.04
# Tienda 3 - Calificación promedio: 4.05
# Tienda 4 - Calificación promedio: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
print("\n🏆 PRODUCTOS MÁS Y MENOS VENDIDOS")
for i, df in enumerate(tiendas, start=1):
    ventas_productos = df['producto'].value_counts()
    producto_mas_vendido = ventas_productos.idxmax()
    cantidad_mas_vendido = ventas_productos.max()
    producto_menos_vendido = ventas_productos.idxmin()
    cantidad_menos_vendido = ventas_productos.min()

    print(f"\nTienda {i}:")
    print(f"  Más vendido: {producto_mas_vendido} ({cantidad_mas_vendido} ventas)")
    print(f"  Menos vendido: {producto_menos_vendido} ({cantidad_menos_vendido} ventas)")
# Out:
# 🏆 PRODUCTOS MÁS Y MENOS VENDIDOS
#
# Tienda 1:
#   Más vendido: Microondas (60 ventas)
#   Menos vendido: Auriculares con micrófono (33 ventas)
#
# Tienda 2:
#   Más vendido: Iniciando en programación (65 ventas)
#   Menos vendido: Juego de mesa (32 ventas)
#
# Tienda 3:
#   Más vendido: Kit de bancas (57 ventas)
#   Menos vendido: Bloques de construcción (35 ventas)
#
# Tienda 4:
#   Más vendido: Cama box (62 ventas)
#   Menos vendido: Guitarra eléctrica (33 ventas)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
print("\n🚚 COSTO DE ENVÍO PROMEDIO POR TIENDA")
for i, df in enumerate([tienda, tienda2, tienda3, tienda4], start=1):
    promedio_envio = df['costo_de_envio'].mean()
    print(f"Tienda {i} - Costo de envío promedio: ${promedio_envio:.2f}")
# Out:
# 🚚 COSTO DE ENVÍO PROMEDIO POR TIENDA
# Tienda 1 - Costo de envío promedio: $26018.61
# Tienda 2 - Costo de envío promedio: $25216.24
# Tienda 3 - Costo de envío promedio: $24805.68
# Tienda 4 - Costo de envío promedio: $23459.46

# %% [markdown]
# ##****Visualizacion****

# %% [markdown]
# ##****Ingresos por tienda (Barras)****

# %%
nombres_tiendas = [f"Tienda {i}" for i in range(1, 5)]
ingresos = [df['precio'].sum() for df in [tienda, tienda2, tienda3, tienda4]]

plt.figure(figsize=(7,4))
plt.bar(nombres_tiendas, ingresos)
plt.title("Ingresos Totales por Tienda")
plt.xlabel("Tienda")
plt.ylabel("Ingreso total")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##****Distribución de categorías – Tienda 1****

# %%
top_n = 6
vc = tienda['categoria_del_producto'].value_counts()

# Top N + "Otros"
vc_top = vc.head(top_n)
otros = vc.iloc[top_n:].sum()
if otros > 0:
    vc_top.loc['Otros'] = otros

plt.figure(figsize=(6,6))
plt.pie(vc_top.values, labels=vc_top.index, autopct='%1.1f%%', startangle=90)
plt.title("Composición de Categorías - Tienda 1 (Top 6 + Otros)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##****Dispersión – Precio vs Costo de envío (Tienda 1) (tipo 3)****

# %%
df_plot = tienda.sample(min(1000, len(tienda)), random_state=42)

plt.figure(figsize=(7,5))
plt.scatter(df_plot['precio'], df_plot['costo_de_envio'], alpha=0.6)
plt.title("Relación Precio vs Costo de envío - Tienda 1")
plt.xlabel("Precio")
plt.ylabel("Costo de envío")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##****Barras horizontales – Top 10 categorías por tienda ( tipo 1 con variación)****

# %%
for i, df in enumerate([tienda, tienda2, tienda3, tienda4], start=1):
    top_cats = df['categoria_del_producto'].value_counts().head(10)
    plt.figure(figsize=(7,5))
    plt.barh(top_cats.index[::-1], top_cats.values[::-1])
    plt.title(f"Top 10 Categorías - Tienda {i}")
    plt.xlabel("Nº de ventas")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##****Barras – Calificación promedio por tienda****

# %%
ratings = [df['calificacion'].mean() for df in [tienda, tienda2, tienda3, tienda4]]

plt.figure(figsize=(7,4))
plt.bar(nombres_tiendas, ratings)
plt.title("Calificación Promedio por Tienda")
plt.xlabel("Tienda")
plt.ylabel("Calificación promedio")
plt.ylim(0, max(5, max(ratings)+0.2))  # asumiendo escala 1–5
plt.tight_layout()
plt.show()

# %% [markdown]
# ##****Barras – Costo de envío promedio por tienda****
#
# ---

# %%
envios = [df['costo_de_envio'].mean() for df in [tienda, tienda2, tienda3, tienda4]]

plt.figure(figsize=(7,4))
plt.bar(nombres_tiendas, envios)
plt.title("Costo de Envío Promedio por Tienda")
plt.xlabel("Tienda")
plt.ylabel("Costo de envío promedio")
plt.tight_layout()
plt.show()

# %% [markdown]
# ###****Informe final****

# %%
# --- 7. Informe Final y Ranking Ponderado ---

# 1. Métricas clave
ingresos = [df['precio'].sum() for df in [tienda, tienda2, tienda3, tienda4]]
calificaciones = [df['calificacion'].mean() for df in [tienda, tienda2, tienda3, tienda4]]
envios = [df['costo_de_envio'].mean() for df in [tienda, tienda2, tienda3, tienda4]]

# 2. Normalización (para comparar métricas en la misma escala)
import numpy as np

def normalizar(valores, invertido=False):
    arr = np.array(valores)
    if invertido:  # Para costos, donde menor es mejor
        arr = arr.max() - arr
    return (arr - arr.min()) / (arr.max() - arr.min())

norm_ingresos = normalizar(ingresos)
norm_calificaciones = normalizar(calificaciones)
norm_envios = normalizar(envios, invertido=True)

# 3. Score ponderado (40% ingresos, 40% calificación, 20% envío)
scores = 0.4 * norm_ingresos + 0.4 * norm_calificaciones + 0.2 * norm_envios
ranking = sorted(enumerate(scores, start=1), key=lambda x: x[1], reverse=True)

# 4. Resultados destacados
mejor_tienda_ingresos = ingresos.index(max(ingresos)) + 1
mejor_tienda_calif = calificaciones.index(max(calificaciones)) + 1
mejor_tienda_envio = envios.index(min(envios)) + 1
mejor_tienda_global = ranking[0][0]

# 5. Informe final
print("📊 INFORME FINAL")
print("="*50)
print(f"💰 Ingresos totales por tienda: {ingresos}")
print(f"⭐ Calificaciones promedio por tienda: {calificaciones}")
print(f"🚚 Costo de envío promedio por tienda: {envios}")
print()
print(f"🏆 Mayor ingreso: Tienda {mejor_tienda_ingresos}")
print(f"🏆 Mejor calificación: Tienda {mejor_tienda_calif}")
print(f"🏆 Envío más barato: Tienda {mejor_tienda_envio}")
print(f"🌟 Mejor rendimiento global (ponderado): Tienda {mejor_tienda_global}")
print()
print("📈 Ranking global de tiendas:")
for t, score in ranking:
    print(f"  - Tienda {t}: Score {score:.2f}")
print()
print("🔍 RECOMENDACIONES:")
print("- Fortalecer el inventario y marketing en la tienda con mayores ingresos para consolidar liderazgo.")
print("- Revisar estrategias de atención al cliente en tiendas con calificaciones más bajas.")
print("- Analizar viabilidad de reducir costos logísticos en tiendas con envíos más caros.")
print("- Replicar estrategias de la tienda con mejor balance entre ingresos y calificación en las demás.")
print("- Considerar el puntaje ponderado como referencia para inversiones estratégicas.")
# Out:
# 📊 INFORME FINAL
# ...
# 💰 Ingresos totales por tienda: [np.float64(1150880400.0), np.float64(1116343500.0), np.float64(1098019600.0), np.float64(1038375700.0)]
# ⭐ Calificaciones promedio por tienda: [np.float64(3.976685036032217), np.float64(4.037303942348453), np.float64(4.048325561678677), np.float64(3.9957591178965224)]
# 🚚 Costo de envío promedio por tienda: [np.float64(26018.60958033065), np.float64(25216.235693090293), np.float64(24805.680373039424), np.float64(23459.457167090754)]
#
# 🏆 Mayor ingreso: Tienda 1
# 🏆 Mejor calificación: Tienda 3
# 🏆 Envío más barato: Tienda 4
# 🌟 Mejor rendimiento global (ponderado): Tienda 3
#
# 📈 Ranking global de tiendas:
#   - Tienda 3: Score 0.71
#   - Tienda 2: Score 0.68
#   - Tienda 1: Score 0.40
#   - Tienda 4: Score 0.31
#
# 🔍 RECOMENDACIONES:
# - Fortalecer el inventario y marketing en la tienda con mayores ingresos para consolidar liderazgo.
# - Revisar estrategias de atención al cliente en tiendas con calificaciones más bajas.
# ...

# %% [markdown]
# ##****¡Extra! Análisis del desempeño geográfico****`

# %% [markdown]
# Esta actividad es un extra, por lo tanto es OPCIONAL.
#
# En este extra, tendrás el desafío de explorar las coordenadas geográficas de los datos de ventas e identificar patrones relacionados con la ubicación de las compras. Al utilizar las columnas de latitud y longitud, puede generar visualizaciones para comprender cómo varían las ventas según la ubicación geográfica.
#
# Desafío:
#
# Utilice los datos de latitud (lat) y longitud (lon) para mapear las ventas de cada tienda y analizar la distribución geográfica de los productos vendidos.
#
# Genere gráficos de dispersión o mapas de calor (Heatmaps) para visualizar datos e identificar áreas con la mayor concentración de ventas.
#
# Explore si algunas tiendas tienen un rendimiento superior o inferior al esperado en determinadas regiones e identifique si existen patrones geográficos que puedan influir en el rendimiento de las tiendas.
#
# Sugerencias:
#
# Puede utilizar la biblioteca Matplotlib para gráficos de dispersión o incluso integrarla con otras bibliotecas como Folium para generar mapas interactivos si desea ir más allá.
#
# Analice cómo las variables geográficas influyen en los ingresos y las calificaciones de las tiendas.

# %%
import matplotlib.pyplot as plt

# Lista de tiendas y nombres
tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
colores = ["red", "blue", "green", "orange"]

plt.figure(figsize=(10, 6))

for df, nombre, color in zip(tiendas, nombres_tiendas, colores):
    plt.scatter(df["lon"], df["lat"], label=nombre, alpha=0.6, c=color, s=50)

plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.title("Distribución Geográfica de Ventas por Tienda")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##****Mapa interactivo con Folium****

# %%
# Ejemplo de gráfico de dispersión corregido
import matplotlib.pyplot as plt

tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
colores = ["red", "blue", "green", "orange"]

plt.figure(figsize=(10, 6))

for df, nombre, color in zip(tiendas, nombres_tiendas, colores):
    plt.scatter(df["lon"], df["lat"], label=nombre, alpha=0.6, c=color, s=50)

plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.title("Distribución Geográfica de Ventas por Tienda")
plt.legend()
plt.grid(True)
plt.show()
